# %%
from deepinv.physics.generator import DiffractionBlurGenerator
from src.utils.display_utils import show_images
import matplotlib.pyplot as plt
from PIL import Image
import torch
import torchvision.transforms as transform
from product_convolution import *

# %%
device = 'cuda'
dtype = torch.float32
torch.set_default_device(device)
torch.set_default_dtype(dtype)

# %% [markdown]
# ## Plot utils

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib import gridspec
from torch import Tensor
import numpy as np
from typing import List, Optional, Tuple, Union
import warnings
warnings.filterwarnings("ignore", module="matplotlib\..*")

_TensorArray = Union[Tensor, np.ndarray]

def to_numpy_image(input):
    if isinstance(input, Tensor):
        if input.dim() == 3:
            return input.detach().cpu().permute(1, 2, 0).numpy()
        elif input.dim() == 4:
            return input.detach().cpu().permute(0, 2, 3, 1).numpy()

    elif isinstance(input, np.ndarray):
        print("Warning: input is already a numpy array")
        return input
    else:
        raise ValueError(f"Cannot convert {type(input)} to numpy image")
def show_images(
    imgs: Union[_TensorArray, List[_TensorArray], Tuple[_TensorArray]],
    title: List[str] = None,
    suptitle: str = None,
    ncols: int = None,
    colorbar: Optional[bool] = False,
    cmap: str = None,
    vmin: Optional[float] = None,
    vmax: Optional[float] = None,
    savename: Optional[str] = None,
    figsize: Optional[int] = 3,
    interpolation: Optional[str] = None,
):

    if isinstance(imgs, List) or isinstance(imgs, Tuple):
        if isinstance(imgs[0], np.ndarray):
            imgs = np.concatenate(imgs, axis=0)
        elif isinstance(imgs[0], torch.Tensor):
            imgs = to_numpy_image(torch.cat(imgs, dim=0))
    else:
        imgs = to_numpy_image(imgs)

    if imgs.ndim == 3:
        H, W, C = imgs.shape
        B = 1
    elif imgs.ndim == 4:
        B, H, W, C = imgs.shape

    if (ncols is not None) and (B % ncols == 0):
        nrows = B // ncols
    else:
        nrows = 1
        ncols = B
    offset = 0 if not colorbar else 0.75
    fig = plt.figure(figsize=(ncols * (figsize + offset), nrows * figsize))
    gs = gridspec.GridSpec(ncols=ncols, nrows=nrows)
    gs.update(wspace=0.025, hspace=0.025)

    if cmap is None:
        cmap = "gray" if C == 1 else None
    i = 0

    if title is None:
        title = [""]
    if len(title) != B:
        title += [""] * (B - len(title))
    with warnings.catch_warnings():
        if nrows > 1 and ncols > 1:
            for r in range(nrows):
                for c in range(ncols):
                    axs = plt.subplot(gs[r, c])
                    im = axs.imshow(
                        imgs[i],
                        vmin=vmin,
                        vmax=vmax,
                        cmap=cmap,
                        interpolation=interpolation,
                    )
                    axs.set_xticks([])
                    axs.set_yticks([])
                    if colorbar:
                        divider = make_axes_locatable(axs)
                        cax = divider.append_axes("right", size="3%", pad=0.1)
                        plt.colorbar(im, cax=cax)
                    if title:
                        axs.set_title(title[i], pad=3)

                    i += 1
        elif nrows > 1 or ncols > 1:
            for c in range(max(ncols, nrows)):
                axs = plt.subplot(gs[c])
                im = axs.imshow(
                    imgs[c], vmin=vmin, vmax=vmax, cmap=cmap, interpolation=interpolation
                )
                axs.set_xticks([])
                axs.set_yticks([])
                if colorbar:
                    divider = make_axes_locatable(axs)
                    cax = divider.append_axes("right", size="3%", pad=0.1)
                    plt.colorbar(im, cax=cax)
                if title:
                    axs.set_title(title[c], pad=3)

        else:
            axs = plt.subplot(gs[0])
            im = axs.imshow(
                imgs.squeeze(), vmin=vmin, vmax=vmax, cmap=cmap, interpolation=interpolation
            )
            axs.set_xticks([])
            axs.set_yticks([])
            if colorbar:
                divider = make_axes_locatable(axs)
                cax = divider.append_axes("right", size="3%", pad=0.1)
                plt.colorbar(im, cax=cax)
            if title:
                axs.set_title(title[0], pad=3)

        if suptitle is not None:
            fig.suptitle(suptitle, y=1.03)
        if savename is not None:
            fig.savefig(savename, bbox_inches='tight')
            plt.close()
        else:
            plt.show()

# %% [markdown]
# ## Test on image

# %%
# %% TEST PRODUCT-CONVOLUTION
path_1 = '/home/minhhai/Works/datasets/FFHQ/images1024x1024/00003.png'
path_2 = '/home/minhhai/Works/datasets/FFHQ/images1024x1024/00014.png'

image_1 = Image.open(path_1)
image_1 = transform.ToTensor()(image_1)

image_2 = Image.open(path_2)
image_2 = transform.ToTensor()(image_2)

image = torch.stack([image_1, image_2], dim=0).cuda()
show_images(image)

# %%
psf_size = (31, 31)
patch_size = (256, 256)
overlap = (128, 128)
image_size = (1024, 1024)
patches = image_to_patches(image, patch_size=patch_size, overlap=overlap)
patch_info = compute_patch_info(image_size, patch_size, overlap)
K = patches.size(2) * patches.size(3)


generator = DiffractionBlurGenerator(
    psf_size, num_channels=3, device=device, dtype=dtype)
h = torch.stack([generator.step(image.size(0))['filter']
                 for _ in range(K)], dim=2)

masks = unity_partition_function_2d(image.shape[-2:], patch_size, overlap)
w, _ = crop_unity_partition_2d(masks, patch_size, overlap, psf_size)
w = w.flatten(0,1).unsqueeze(0).unsqueeze(0)

# show_images(h.transpose(2,1).flatten(0, 1) ** 0.25, ncols=K)
blurry = product_convolution2d_patches(image, w, h, patch_size, overlap)
show_images(blurry)

# %%
import deepinv as dinv
physic = dinv.physics.SpaceVaryingBlur(filters=h, multipliers=w, padding='valid', method='product_convolution2d_patch', patch_size=patch_size, overlap=overlap, device='cuda')
blurry = physic.A(image)
show_images(blurry)

# %% [markdown]
# ## TEST GET-PSF

# %%
psf_size = (31, 31)
patch_size = (128, 128)
overlap = (64, 64)
image_size = (512, 512)
dirac = torch.zeros((1,3) + image_size)
dirac[...,30,30] = 1.
patches = image_to_patches(dirac, patch_size, overlap)
patch_info = compute_patch_info(image_size, patch_size, overlap)
K = patches.size(2) * patches.size(3)


generator = DiffractionBlurGenerator(
    psf_size, num_channels=3, fc=0.2, device=device, dtype=dtype)
h = torch.stack([generator.step(dirac.size(0))['filter']
                 for _ in range(K)], dim=2)

masks = unity_partition_function_2d(dirac.shape[-2:], patch_size, overlap)
w, _ = crop_unity_partition_2d(masks, patch_size, overlap, psf_size)
w = w.flatten(0,1).unsqueeze(0).unsqueeze(0)

# show_images(h.transpose(2,1).flatten(0, 1) ** 0.25, ncols=K)
blurry = product_convolution2d_patches(dirac, w, h, patch_size, overlap)
show_images(blurry ** 0.25)

# %% [markdown]
# ### Simple loops

# %%
patch_size = (128, 128)
overlap = (40, 40)
max_size = 215
for i in range(max_size):
    for j in range(max_size):
        image = torch.zeros(2, 3, 256, 256)
        position = (i, j)
        
        out = get_index_and_position(position,  patch_size, overlap, num_patches = physic.num_patches)
        out_2 = get_index_and_position_2(position,  patch_size, overlap, num_patches = physic.num_patches)

        if out != out_2:
            print(f'---------------{position}-----------------') 
            print(out)
            print(out_2)

# %%
image_size = 128
patch_size = (64, 64)
overlap = (32, 32)
max_size = 128
for i in range(max_size):
    for j in range(max_size):
        image = torch.zeros(2, 3, image_size, image_size)
        position = (i, j)
        index_h, index_w, patch_position_h, patch_position_w = get_index_and_position_2(position,  patch_size, overlap, num_patches = physic.num_patches)
        print(f'---------------{position}-----------------') 
        print(f'index_h {index_h}, index_w {index_w}, position_h {patch_position_h}, position_w {patch_position_w}')
# Out:
# ---------------(0, 0)-----------------
# index_h [0], index_w [0], position_h [0], position_w [0]
# ---------------(0, 1)-----------------
# index_h [0], index_w [0], position_h [0], position_w [1]
# ---------------(0, 2)-----------------
# index_h [0], index_w [0], position_h [0], position_w [2]
# ---------------(0, 3)-----------------
# index_h [0], index_w [0], position_h [0], position_w [3]
# ---------------(0, 4)-----------------
# index_h [0], index_w [0], position_h [0], position_w [4]
# ---------------(0, 5)-----------------
# index_h [0], index_w [0], position_h [0], position_w [5]
# ---------------(0, 6)-----------------
# index_h [0], index_w [0], position_h [0], position_w [6]
# ---------------(0, 7)-----------------
# index_h [0], index_w [0], position_h [0], position_w [7]
# ---------------(0, 8)-----------------
# index_h [0], index_w [0], position_h [0], position_w [8]
# ---------------(0, 9)-----------------
# index_h [0], index_w [0], position_h [0], position_w [9]
# ---------------(0, 10)-----------------
# index_h [0], index_w [0], position_h [0], position_w [10]
# ---------------(0, 11)-----------------
# index_h [0], index_w [0], position_h [0], position_w [11]
# ---------------(0, 12)-----------------
# index_h [0], index_w [0], position_h [0], position_w [12]
# ---------------(0, 13)-----------------
# index_h [0], index_w [0], position_h [0], position_w [13]
# ---------------(0, 14)-----------------
# index_h [0], index_w [0], position_h [0], position_w [14]
# ---------------(0, 15)-----------------
# index_h [0], index_w [0], position_h [0], position_w [15]
# ---------------(0, 16)-----------------
# index_h [0], index_w [0], position_h [0], position_w [16]
# ---------------(0, 17)-----------------
# index_h [0], index_w [0], position_h [0], position_w [17]
# ---------------(0, 18)-----------------
# index_h [0], index_w [0], position_h [0], position_w [18]
# ---------------(0, 19)-----------------
# index_h [0], index_w [0], position_h [0], position_w [19]
# ---------------(0, 20)-----------------
# index_h [0], index_w [0], position_h [0], position_w [20]
# ---------------(0, 21)-----------------
# index_h [0], index_w [0], position_h [0], position_w [21]
# ---------------(0, 22)-----------------
# index_h [0], index_w [0], position_h [0], position_w [22]
# ---------------(0, 23)-----------------
# index_h [0], index_w [0], position_h [0], position_w [23]
# ---------------(0, 24)-----------------
# index_h [0], index_w [0], position_h [0], position_w [24]
# ---------------(0, 25)-----------------
# index_h [0], index_w [0], position_h [0], position_w [25]
# ---------------(0, 26)-----------------
# index_h [0], index_w [0], position_h [0], position_w [26]
# ---------------(0, 27)-----------------
# index_h [0], index_w [0], position_h [0], position_w [27]
# ---------------(0, 28)-----------------
# index_h [0], index_w [0], position_h [0], position_w [28]
# ---------------(0, 29)-----------------
# index_h [0], index_w [0], position_h [0], position_w [29]
# ---------------(0, 30)-----------------
# index_h [0], index_w [0], position_h [0], position_w [30]
# ---------------(0, 31)-----------------
# index_h [0], index_w [0], position_h [0], position_w [31]
# ---------------(0, 32)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [32, 0]
# ---------------(0, 33)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [33, 1]
# ---------------(0, 34)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [34, 2]
# ---------------(0, 35)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [35, 3]
# ---------------(0, 36)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [36, 4]
# ---------------(0, 37)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [37, 5]
# ---------------(0, 38)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [38, 6]
# ---------------(0, 39)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [39, 7]
# ---------------(0, 40)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [40, 8]
# ---------------(0, 41)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [41, 9]
# ---------------(0, 42)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [42, 10]
# ---------------(0, 43)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [43, 11]
# ---------------(0, 44)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [44, 12]
# ---------------(0, 45)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [45, 13]
# ---------------(0, 46)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [46, 14]
# ---------------(0, 47)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [47, 15]
# ---------------(0, 48)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [48, 16]
# ---------------(0, 49)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [49, 17]
# ---------------(0, 50)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [50, 18]
# ---------------(0, 51)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [51, 19]
# ---------------(0, 52)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [52, 20]
# ---------------(0, 53)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [53, 21]
# ---------------(0, 54)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [54, 22]
# ---------------(0, 55)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [55, 23]
# ---------------(0, 56)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [56, 24]
# ---------------(0, 57)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [57, 25]
# ---------------(0, 58)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [58, 26]
# ---------------(0, 59)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [59, 27]
# ---------------(0, 60)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [60, 28]
# ---------------(0, 61)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [61, 29]
# ---------------(0, 62)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [62, 30]
# ---------------(0, 63)-----------------
# index_h [0], index_w [0, 1], position_h [0], position_w [63, 31]
# ---------------(0, 64)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [32, 0]
# ---------------(0, 65)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [33, 1]
# ---------------(0, 66)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [34, 2]
# ---------------(0, 67)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [35, 3]
# ---------------(0, 68)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [36, 4]
# ---------------(0, 69)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [37, 5]
# ---------------(0, 70)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [38, 6]
# ---------------(0, 71)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [39, 7]
# ---------------(0, 72)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [40, 8]
# ---------------(0, 73)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [41, 9]
# ---------------(0, 74)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [42, 10]
# ---------------(0, 75)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [43, 11]
# ---------------(0, 76)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [44, 12]
# ---------------(0, 77)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [45, 13]
# ---------------(0, 78)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [46, 14]
# ---------------(0, 79)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [47, 15]
# ---------------(0, 80)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [48, 16]
# ---------------(0, 81)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [49, 17]
# ---------------(0, 82)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [50, 18]
# ---------------(0, 83)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [51, 19]
# ---------------(0, 84)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [52, 20]
# ---------------(0, 85)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [53, 21]
# ---------------(0, 86)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [54, 22]
# ---------------(0, 87)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [55, 23]
# ---------------(0, 88)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [56, 24]
# ---------------(0, 89)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [57, 25]
# ---------------(0, 90)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [58, 26]
# ---------------(0, 91)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [59, 27]
# ---------------(0, 92)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [60, 28]
# ---------------(0, 93)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [61, 29]
# ---------------(0, 94)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [62, 30]
# ---------------(0, 95)-----------------
# index_h [0], index_w [1, 2], position_h [0], position_w [63, 31]
# ---------------(0, 96)-----------------
# index_h [0], index_w [2], position_h [0], position_w [32]
# ---------------(0, 97)-----------------
# index_h [0], index_w [2], position_h [0], position_w [33]
# ---------------(0, 98)-----------------
# index_h [0], index_w [2], position_h [0], position_w [34]
# ---------------(0, 99)-----------------
# index_h [0], index_w [2], position_h [0], position_w [35]
# ---------------(0, 100)-----------------
# index_h [0], index_w [2], position_h [0], position_w [36]
# ---------------(0, 101)-----------------
# index_h [0], index_w [2], position_h [0], position_w [37]
# ---------------(0, 102)-----------------
# index_h [0], index_w [2], position_h [0], position_w [38]
# ---------------(0, 103)-----------------
# index_h [0], index_w [2], position_h [0], position_w [39]
# ---------------(0, 104)-----------------
# index_h [0], index_w [2], position_h [0], position_w [40]
# ---------------(0, 105)-----------------
# index_h [0], index_w [2], position_h [0], position_w [41]
# ---------------(0, 106)-----------------
# index_h [0], index_w [2], position_h [0], position_w [42]
# ---------------(0, 107)-----------------
# index_h [0], index_w [2], position_h [0], position_w [43]
# ---------------(0, 108)-----------------
# index_h [0], index_w [2], position_h [0], position_w [44]
# ---------------(0, 109)-----------------
# index_h [0], index_w [2], position_h [0], position_w [45]
# ---------------(0, 110)-----------------
# index_h [0], index_w [2], position_h [0], position_w [46]
# ---------------(0, 111)-----------------
# index_h [0], index_w [2], position_h [0], position_w [47]
# ---------------(0, 112)-----------------
# index_h [0], index_w [2], position_h [0], position_w [48]
# ---------------(0, 113)-----------------
# index_h [0], index_w [2], position_h [0], position_w [49]
# ---------------(0, 114)-----------------
# index_h [0], index_w [2], position_h [0], position_w [50]
# ---------------(0, 115)-----------------
# index_h [0], index_w [2], position_h [0], position_w [51]
# ---------------(0, 116)-----------------
# index_h [0], index_w [2], position_h [0], position_w [52]
# ---------------(0, 117)-----------------
# index_h [0], index_w [2], position_h [0], position_w [53]
# ---------------(0, 118)-----------------
# index_h [0], index_w [2], position_h [0], position_w [54]
# ---------------(0, 119)-----------------
# index_h [0], index_w [2], position_h [0], position_w [55]
# ---------------(0, 120)-----------------
# index_h [0], index_w [2], position_h [0], position_w [56]
# ---------------(0, 121)-----------------
# index_h [0], index_w [2], position_h [0], position_w [57]
# ---------------(0, 122)-----------------
# index_h [0], index_w [2], position_h [0], position_w [58]
# ---------------(0, 123)-----------------
# index_h [0], index_w [2], position_h [0], position_w [59]
# ---------------(0, 124)-----------------
# index_h [0], index_w [2], position_h [0], position_w [60]
# ---------------(0, 125)-----------------
# index_h [0], index_w [2], position_h [0], position_w [61]
# ---------------(0, 126)-----------------
# index_h [0], index_w [2], position_h [0], position_w [62]
# ---------------(0, 127)-----------------
# index_h [0], index_w [2], position_h [0], position_w [63]
# ---------------(1, 0)-----------------
# index_h [0], index_w [0], position_h [1], position_w [0]
# ---------------(1, 1)-----------------
# index_h [0], index_w [0], position_h [1], position_w [1]
# ---------------(1, 2)-----------------
# index_h [0], index_w [0], position_h [1], position_w [2]
# ---------------(1, 3)-----------------
# index_h [0], index_w [0], position_h [1], position_w [3]
# ---------------(1, 4)-----------------
# index_h [0], index_w [0], position_h [1], position_w [4]
# ---------------(1, 5)-----------------
# index_h [0], index_w [0], position_h [1], position_w [5]
# ---------------(1, 6)-----------------
# index_h [0], index_w [0], position_h [1], position_w [6]
# ---------------(1, 7)-----------------
# index_h [0], index_w [0], position_h [1], position_w [7]
# ---------------(1, 8)-----------------
# index_h [0], index_w [0], position_h [1], position_w [8]
# ---------------(1, 9)-----------------
# index_h [0], index_w [0], position_h [1], position_w [9]
# ---------------(1, 10)-----------------
# index_h [0], index_w [0], position_h [1], position_w [10]
# ---------------(1, 11)-----------------
# index_h [0], index_w [0], position_h [1], position_w [11]
# ---------------(1, 12)-----------------
# index_h [0], index_w [0], position_h [1], position_w [12]
# ---------------(1, 13)-----------------
# index_h [0], index_w [0], position_h [1], position_w [13]
# ---------------(1, 14)-----------------
# index_h [0], index_w [0], position_h [1], position_w [14]
# ---------------(1, 15)-----------------
# index_h [0], index_w [0], position_h [1], position_w [15]
# ---------------(1, 16)-----------------
# index_h [0], index_w [0], position_h [1], position_w [16]
# ---------------(1, 17)-----------------
# index_h [0], index_w [0], position_h [1], position_w [17]
# ---------------(1, 18)-----------------
# index_h [0], index_w [0], position_h [1], position_w [18]
# ---------------(1, 19)-----------------
# index_h [0], index_w [0], position_h [1], position_w [19]
# ---------------(1, 20)-----------------
# index_h [0], index_w [0], position_h [1], position_w [20]
# ---------------(1, 21)-----------------
# index_h [0], index_w [0], position_h [1], position_w [21]
# ---------------(1, 22)-----------------
# index_h [0], index_w [0], position_h [1], position_w [22]
# ---------------(1, 23)-----------------
# index_h [0], index_w [0], position_h [1], position_w [23]
# ---------------(1, 24)-----------------
# index_h [0], index_w [0], position_h [1], position_w [24]
# ---------------(1, 25)-----------------
# index_h [0], index_w [0], position_h [1], position_w [25]
# ---------------(1, 26)-----------------
# index_h [0], index_w [0], position_h [1], position_w [26]
# ---------------(1, 27)-----------------
# index_h [0], index_w [0], position_h [1], position_w [27]
# ---------------(1, 28)-----------------
# index_h [0], index_w [0], position_h [1], position_w [28]
# ---------------(1, 29)-----------------
# index_h [0], index_w [0], position_h [1], position_w [29]
# ---------------(1, 30)-----------------
# index_h [0], index_w [0], position_h [1], position_w [30]
# ---------------(1, 31)-----------------
# index_h [0], index_w [0], position_h [1], position_w [31]
# ---------------(1, 32)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [32, 0]
# ---------------(1, 33)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [33, 1]
# ---------------(1, 34)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [34, 2]
# ---------------(1, 35)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [35, 3]
# ---------------(1, 36)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [36, 4]
# ---------------(1, 37)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [37, 5]
# ---------------(1, 38)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [38, 6]
# ---------------(1, 39)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [39, 7]
# ---------------(1, 40)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [40, 8]
# ---------------(1, 41)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [41, 9]
# ---------------(1, 42)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [42, 10]
# ---------------(1, 43)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [43, 11]
# ---------------(1, 44)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [44, 12]
# ---------------(1, 45)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [45, 13]
# ---------------(1, 46)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [46, 14]
# ---------------(1, 47)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [47, 15]
# ---------------(1, 48)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [48, 16]
# ---------------(1, 49)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [49, 17]
# ---------------(1, 50)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [50, 18]
# ---------------(1, 51)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [51, 19]
# ---------------(1, 52)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [52, 20]
# ---------------(1, 53)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [53, 21]
# ---------------(1, 54)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [54, 22]
# ---------------(1, 55)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [55, 23]
# ---------------(1, 56)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [56, 24]
# ---------------(1, 57)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [57, 25]
# ---------------(1, 58)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [58, 26]
# ---------------(1, 59)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [59, 27]
# ---------------(1, 60)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [60, 28]
# ---------------(1, 61)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [61, 29]
# ---------------(1, 62)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [62, 30]
# ---------------(1, 63)-----------------
# index_h [0], index_w [0, 1], position_h [1], position_w [63, 31]
# ---------------(1, 64)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [32, 0]
# ---------------(1, 65)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [33, 1]
# ---------------(1, 66)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [34, 2]
# ---------------(1, 67)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [35, 3]
# ---------------(1, 68)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [36, 4]
# ---------------(1, 69)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [37, 5]
# ---------------(1, 70)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [38, 6]
# ---------------(1, 71)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [39, 7]
# ---------------(1, 72)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [40, 8]
# ---------------(1, 73)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [41, 9]
# ---------------(1, 74)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [42, 10]
# ---------------(1, 75)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [43, 11]
# ---------------(1, 76)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [44, 12]
# ---------------(1, 77)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [45, 13]
# ---------------(1, 78)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [46, 14]
# ---------------(1, 79)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [47, 15]
# ---------------(1, 80)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [48, 16]
# ---------------(1, 81)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [49, 17]
# ---------------(1, 82)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [50, 18]
# ---------------(1, 83)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [51, 19]
# ---------------(1, 84)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [52, 20]
# ---------------(1, 85)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [53, 21]
# ---------------(1, 86)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [54, 22]
# ---------------(1, 87)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [55, 23]
# ---------------(1, 88)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [56, 24]
# ---------------(1, 89)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [57, 25]
# ---------------(1, 90)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [58, 26]
# ---------------(1, 91)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [59, 27]
# ---------------(1, 92)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [60, 28]
# ---------------(1, 93)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [61, 29]
# ---------------(1, 94)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [62, 30]
# ---------------(1, 95)-----------------
# index_h [0], index_w [1, 2], position_h [1], position_w [63, 31]
# ---------------(1, 96)-----------------
# index_h [0], index_w [2], position_h [1], position_w [32]
# ---------------(1, 97)-----------------
# index_h [0], index_w [2], position_h [1], position_w [33]
# ---------------(1, 98)-----------------
# index_h [0], index_w [2], position_h [1], position_w [34]
# ---------------(1, 99)-----------------
# index_h [0], index_w [2], position_h [1], position_w [35]
# ---------------(1, 100)-----------------
# index_h [0], index_w [2], position_h [1], position_w [36]
# ---------------(1, 101)-----------------
# index_h [0], index_w [2], position_h [1], position_w [37]
# ---------------(1, 102)-----------------
# index_h [0], index_w [2], position_h [1], position_w [38]
# ---------------(1, 103)-----------------
# index_h [0], index_w [2], position_h [1], position_w [39]
# ---------------(1, 104)-----------------
# index_h [0], index_w [2], position_h [1], position_w [40]
# ---------------(1, 105)-----------------
# index_h [0], index_w [2], position_h [1], position_w [41]
# ---------------(1, 106)-----------------
# index_h [0], index_w [2], position_h [1], position_w [42]
# ---------------(1, 107)-----------------
# index_h [0], index_w [2], position_h [1], position_w [43]
# ---------------(1, 108)-----------------
# index_h [0], index_w [2], position_h [1], position_w [44]
# ---------------(1, 109)-----------------
# index_h [0], index_w [2], position_h [1], position_w [45]
# ---------------(1, 110)-----------------
# index_h [0], index_w [2], position_h [1], position_w [46]
# ---------------(1, 111)-----------------
# index_h [0], index_w [2], position_h [1], position_w [47]
# ---------------(1, 112)-----------------
# index_h [0], index_w [2], position_h [1], position_w [48]
# ---------------(1, 113)-----------------
# index_h [0], index_w [2], position_h [1], position_w [49]
# ---------------(1, 114)-----------------
# index_h [0], index_w [2], position_h [1], position_w [50]
# ---------------(1, 115)-----------------
# index_h [0], index_w [2], position_h [1], position_w [51]
# ---------------(1, 116)-----------------
# index_h [0], index_w [2], position_h [1], position_w [52]
# ---------------(1, 117)-----------------
# index_h [0], index_w [2], position_h [1], position_w [53]
# ---------------(1, 118)-----------------
# index_h [0], index_w [2], position_h [1], position_w [54]
# ---------------(1, 119)-----------------
# index_h [0], index_w [2], position_h [1], position_w [55]
# ---------------(1, 120)-----------------
# index_h [0], index_w [2], position_h [1], position_w [56]
# ---------------(1, 121)-----------------
# index_h [0], index_w [2], position_h [1], position_w [57]
# ---------------(1, 122)-----------------
# index_h [0], index_w [2], position_h [1], position_w [58]
# ---------------(1, 123)-----------------
# index_h [0], index_w [2], position_h [1], position_w [59]
# ---------------(1, 124)-----------------
# index_h [0], index_w [2], position_h [1], position_w [60]
# ---------------(1, 125)-----------------
# index_h [0], index_w [2], position_h [1], position_w [61]
# ---------------(1, 126)-----------------
# index_h [0], index_w [2], position_h [1], position_w [62]
# ---------------(1, 127)-----------------
# index_h [0], index_w [2], position_h [1], position_w [63]
# ---------------(2, 0)-----------------
# index_h [0], index_w [0], position_h [2], position_w [0]
# ---------------(2, 1)-----------------
# index_h [0], index_w [0], position_h [2], position_w [1]
# ---------------(2, 2)-----------------
# index_h [0], index_w [0], position_h [2], position_w [2]
# ---------------(2, 3)-----------------
# index_h [0], index_w [0], position_h [2], position_w [3]
# ---------------(2, 4)-----------------
# index_h [0], index_w [0], position_h [2], position_w [4]
# ---------------(2, 5)-----------------
# index_h [0], index_w [0], position_h [2], position_w [5]
# ---------------(2, 6)-----------------
# index_h [0], index_w [0], position_h [2], position_w [6]
# ---------------(2, 7)-----------------
# index_h [0], index_w [0], position_h [2], position_w [7]
# ---------------(2, 8)-----------------
# index_h [0], index_w [0], position_h [2], position_w [8]
# ---------------(2, 9)-----------------
# index_h [0], index_w [0], position_h [2], position_w [9]
# ---------------(2, 10)-----------------
# index_h [0], index_w [0], position_h [2], position_w [10]
# ---------------(2, 11)-----------------
# index_h [0], index_w [0], position_h [2], position_w [11]
# ---------------(2, 12)-----------------
# index_h [0], index_w [0], position_h [2], position_w [12]
# ---------------(2, 13)-----------------
# index_h [0], index_w [0], position_h [2], position_w [13]
# ---------------(2, 14)-----------------
# index_h [0], index_w [0], position_h [2], position_w [14]
# ---------------(2, 15)-----------------
# index_h [0], index_w [0], position_h [2], position_w [15]
# ---------------(2, 16)-----------------
# index_h [0], index_w [0], position_h [2], position_w [16]
# ---------------(2, 17)-----------------
# index_h [0], index_w [0], position_h [2], position_w [17]
# ---------------(2, 18)-----------------
# index_h [0], index_w [0], position_h [2], position_w [18]
# ---------------(2, 19)-----------------
# index_h [0], index_w [0], position_h [2], position_w [19]
# ---------------(2, 20)-----------------
# index_h [0], index_w [0], position_h [2], position_w [20]
# ---------------(2, 21)-----------------
# index_h [0], index_w [0], position_h [2], position_w [21]
# ---------------(2, 22)-----------------
# index_h [0], index_w [0], position_h [2], position_w [22]
# ---------------(2, 23)-----------------
# index_h [0], index_w [0], position_h [2], position_w [23]
# ---------------(2, 24)-----------------
# index_h [0], index_w [0], position_h [2], position_w [24]
# ---------------(2, 25)-----------------
# index_h [0], index_w [0], position_h [2], position_w [25]
# ---------------(2, 26)-----------------
# index_h [0], index_w [0], position_h [2], position_w [26]
# ---------------(2, 27)-----------------
# index_h [0], index_w [0], position_h [2], position_w [27]
# ---------------(2, 28)-----------------
# index_h [0], index_w [0], position_h [2], position_w [28]
# ---------------(2, 29)-----------------
# index_h [0], index_w [0], position_h [2], position_w [29]
# ---------------(2, 30)-----------------
# index_h [0], index_w [0], position_h [2], position_w [30]
# ---------------(2, 31)-----------------
# index_h [0], index_w [0], position_h [2], position_w [31]
# ---------------(2, 32)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [32, 0]
# ---------------(2, 33)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [33, 1]
# ---------------(2, 34)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [34, 2]
# ---------------(2, 35)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [35, 3]
# ---------------(2, 36)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [36, 4]
# ---------------(2, 37)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [37, 5]
# ---------------(2, 38)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [38, 6]
# ---------------(2, 39)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [39, 7]
# ---------------(2, 40)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [40, 8]
# ---------------(2, 41)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [41, 9]
# ---------------(2, 42)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [42, 10]
# ---------------(2, 43)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [43, 11]
# ---------------(2, 44)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [44, 12]
# ---------------(2, 45)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [45, 13]
# ---------------(2, 46)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [46, 14]
# ---------------(2, 47)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [47, 15]
# ---------------(2, 48)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [48, 16]
# ---------------(2, 49)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [49, 17]
# ---------------(2, 50)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [50, 18]
# ---------------(2, 51)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [51, 19]
# ---------------(2, 52)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [52, 20]
# ---------------(2, 53)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [53, 21]
# ---------------(2, 54)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [54, 22]
# ---------------(2, 55)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [55, 23]
# ---------------(2, 56)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [56, 24]
# ---------------(2, 57)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [57, 25]
# ---------------(2, 58)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [58, 26]
# ---------------(2, 59)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [59, 27]
# ---------------(2, 60)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [60, 28]
# ---------------(2, 61)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [61, 29]
# ---------------(2, 62)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [62, 30]
# ---------------(2, 63)-----------------
# index_h [0], index_w [0, 1], position_h [2], position_w [63, 31]
# ---------------(2, 64)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [32, 0]
# ---------------(2, 65)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [33, 1]
# ---------------(2, 66)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [34, 2]
# ---------------(2, 67)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [35, 3]
# ---------------(2, 68)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [36, 4]
# ---------------(2, 69)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [37, 5]
# ---------------(2, 70)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [38, 6]
# ---------------(2, 71)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [39, 7]
# ---------------(2, 72)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [40, 8]
# ---------------(2, 73)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [41, 9]
# ---------------(2, 74)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [42, 10]
# ---------------(2, 75)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [43, 11]
# ---------------(2, 76)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [44, 12]
# ---------------(2, 77)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [45, 13]
# ---------------(2, 78)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [46, 14]
# ---------------(2, 79)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [47, 15]
# ---------------(2, 80)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [48, 16]
# ---------------(2, 81)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [49, 17]
# ---------------(2, 82)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [50, 18]
# ---------------(2, 83)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [51, 19]
# ---------------(2, 84)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [52, 20]
# ---------------(2, 85)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [53, 21]
# ---------------(2, 86)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [54, 22]
# ---------------(2, 87)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [55, 23]
# ---------------(2, 88)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [56, 24]
# ---------------(2, 89)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [57, 25]
# ---------------(2, 90)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [58, 26]
# ---------------(2, 91)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [59, 27]
# ---------------(2, 92)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [60, 28]
# ---------------(2, 93)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [61, 29]
# ---------------(2, 94)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [62, 30]
# ---------------(2, 95)-----------------
# index_h [0], index_w [1, 2], position_h [2], position_w [63, 31]
# ---------------(2, 96)-----------------
# index_h [0], index_w [2], position_h [2], position_w [32]
# ---------------(2, 97)-----------------
# index_h [0], index_w [2], position_h [2], position_w [33]
# ---------------(2, 98)-----------------
# index_h [0], index_w [2], position_h [2], position_w [34]
# ---------------(2, 99)-----------------
# index_h [0], index_w [2], position_h [2], position_w [35]
# ---------------(2, 100)-----------------
# index_h [0], index_w [2], position_h [2], position_w [36]
# ---------------(2, 101)-----------------
# index_h [0], index_w [2], position_h [2], position_w [37]
# ---------------(2, 102)-----------------
# index_h [0], index_w [2], position_h [2], position_w [38]
# ---------------(2, 103)-----------------
# index_h [0], index_w [2], position_h [2], position_w [39]
# ---------------(2, 104)-----------------
# index_h [0], index_w [2], position_h [2], position_w [40]
# ---------------(2, 105)-----------------
# index_h [0], index_w [2], position_h [2], position_w [41]
# ---------------(2, 106)-----------------
# index_h [0], index_w [2], position_h [2], position_w [42]
# ---------------(2, 107)-----------------
# index_h [0], index_w [2], position_h [2], position_w [43]
# ---------------(2, 108)-----------------
# index_h [0], index_w [2], position_h [2], position_w [44]
# ---------------(2, 109)-----------------
# index_h [0], index_w [2], position_h [2], position_w [45]
# ---------------(2, 110)-----------------
# index_h [0], index_w [2], position_h [2], position_w [46]
# ---------------(2, 111)-----------------
# index_h [0], index_w [2], position_h [2], position_w [47]
# ---------------(2, 112)-----------------
# index_h [0], index_w [2], position_h [2], position_w [48]
# ---------------(2, 113)-----------------
# index_h [0], index_w [2], position_h [2], position_w [49]
# ---------------(2, 114)-----------------
# index_h [0], index_w [2], position_h [2], position_w [50]
# ---------------(2, 115)-----------------
# index_h [0], index_w [2], position_h [2], position_w [51]
# ---------------(2, 116)-----------------
# index_h [0], index_w [2], position_h [2], position_w [52]
# ---------------(2, 117)-----------------
# index_h [0], index_w [2], position_h [2], position_w [53]
# ---------------(2, 118)-----------------
# index_h [0], index_w [2], position_h [2], position_w [54]
# ---------------(2, 119)-----------------
# index_h [0], index_w [2], position_h [2], position_w [55]
# ---------------(2, 120)-----------------
# index_h [0], index_w [2], position_h [2], position_w [56]
# ---------------(2, 121)-----------------
# index_h [0], index_w [2], position_h [2], position_w [57]
# ---------------(2, 122)-----------------
# index_h [0], index_w [2], position_h [2], position_w [58]
# ---------------(2, 123)-----------------
# index_h [0], index_w [2], position_h [2], position_w [59]
# ---------------(2, 124)-----------------
# index_h [0], index_w [2], position_h [2], position_w [60]
# ---------------(2, 125)-----------------
# index_h [0], index_w [2], position_h [2], position_w [61]
# ---------------(2, 126)-----------------
# index_h [0], index_w [2], position_h [2], position_w [62]
# ---------------(2, 127)-----------------
# index_h [0], index_w [2], position_h [2], position_w [63]
# ---------------(3, 0)-----------------
# index_h [0], index_w [0], position_h [3], position_w [0]
# ---------------(3, 1)-----------------
# index_h [0], index_w [0], position_h [3], position_w [1]
# ---------------(3, 2)-----------------
# index_h [0], index_w [0], position_h [3], position_w [2]
# ---------------(3, 3)-----------------
# index_h [0], index_w [0], position_h [3], position_w [3]
# ---------------(3, 4)-----------------
# index_h [0], index_w [0], position_h [3], position_w [4]
# ---------------(3, 5)-----------------
# index_h [0], index_w [0], position_h [3], position_w [5]
# ---------------(3, 6)-----------------
# index_h [0], index_w [0], position_h [3], position_w [6]
# ---------------(3, 7)-----------------
# index_h [0], index_w [0], position_h [3], position_w [7]
# ---------------(3, 8)-----------------
# index_h [0], index_w [0], position_h [3], position_w [8]
# ---------------(3, 9)-----------------
# index_h [0], index_w [0], position_h [3], position_w [9]
# ---------------(3, 10)-----------------
# index_h [0], index_w [0], position_h [3], position_w [10]
# ---------------(3, 11)-----------------
# index_h [0], index_w [0], position_h [3], position_w [11]
# ---------------(3, 12)-----------------
# index_h [0], index_w [0], position_h [3], position_w [12]
# ---------------(3, 13)-----------------
# index_h [0], index_w [0], position_h [3], position_w [13]
# ---------------(3, 14)-----------------
# index_h [0], index_w [0], position_h [3], position_w [14]
# ---------------(3, 15)-----------------
# index_h [0], index_w [0], position_h [3], position_w [15]
# ---------------(3, 16)-----------------
# index_h [0], index_w [0], position_h [3], position_w [16]
# ---------------(3, 17)-----------------
# index_h [0], index_w [0], position_h [3], position_w [17]
# ---------------(3, 18)-----------------
# index_h [0], index_w [0], position_h [3], position_w [18]
# ---------------(3, 19)-----------------
# index_h [0], index_w [0], position_h [3], position_w [19]
# ---------------(3, 20)-----------------
# index_h [0], index_w [0], position_h [3], position_w [20]
# ---------------(3, 21)-----------------
# index_h [0], index_w [0], position_h [3], position_w [21]
# ---------------(3, 22)-----------------
# index_h [0], index_w [0], position_h [3], position_w [22]
# ---------------(3, 23)-----------------
# index_h [0], index_w [0], position_h [3], position_w [23]
# ---------------(3, 24)-----------------
# index_h [0], index_w [0], position_h [3], position_w [24]
# ---------------(3, 25)-----------------
# index_h [0], index_w [0], position_h [3], position_w [25]
# ---------------(3, 26)-----------------
# index_h [0], index_w [0], position_h [3], position_w [26]
# ---------------(3, 27)-----------------
# index_h [0], index_w [0], position_h [3], position_w [27]
# ---------------(3, 28)-----------------
# index_h [0], index_w [0], position_h [3], position_w [28]
# ---------------(3, 29)-----------------
# index_h [0], index_w [0], position_h [3], position_w [29]
# ---------------(3, 30)-----------------
# index_h [0], index_w [0], position_h [3], position_w [30]
# ---------------(3, 31)-----------------
# index_h [0], index_w [0], position_h [3], position_w [31]
# ---------------(3, 32)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [32, 0]
# ---------------(3, 33)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [33, 1]
# ---------------(3, 34)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [34, 2]
# ---------------(3, 35)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [35, 3]
# ---------------(3, 36)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [36, 4]
# ---------------(3, 37)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [37, 5]
# ---------------(3, 38)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [38, 6]
# ---------------(3, 39)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [39, 7]
# ---------------(3, 40)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [40, 8]
# ---------------(3, 41)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [41, 9]
# ---------------(3, 42)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [42, 10]
# ---------------(3, 43)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [43, 11]
# ---------------(3, 44)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [44, 12]
# ---------------(3, 45)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [45, 13]
# ---------------(3, 46)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [46, 14]
# ---------------(3, 47)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [47, 15]
# ---------------(3, 48)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [48, 16]
# ---------------(3, 49)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [49, 17]
# ---------------(3, 50)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [50, 18]
# ---------------(3, 51)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [51, 19]
# ---------------(3, 52)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [52, 20]
# ---------------(3, 53)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [53, 21]
# ---------------(3, 54)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [54, 22]
# ---------------(3, 55)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [55, 23]
# ---------------(3, 56)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [56, 24]
# ---------------(3, 57)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [57, 25]
# ---------------(3, 58)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [58, 26]
# ---------------(3, 59)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [59, 27]
# ---------------(3, 60)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [60, 28]
# ---------------(3, 61)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [61, 29]
# ---------------(3, 62)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [62, 30]
# ---------------(3, 63)-----------------
# index_h [0], index_w [0, 1], position_h [3], position_w [63, 31]
# ---------------(3, 64)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [32, 0]
# ---------------(3, 65)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [33, 1]
# ---------------(3, 66)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [34, 2]
# ---------------(3, 67)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [35, 3]
# ---------------(3, 68)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [36, 4]
# ---------------(3, 69)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [37, 5]
# ---------------(3, 70)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [38, 6]
# ---------------(3, 71)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [39, 7]
# ---------------(3, 72)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [40, 8]
# ---------------(3, 73)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [41, 9]
# ---------------(3, 74)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [42, 10]
# ---------------(3, 75)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [43, 11]
# ---------------(3, 76)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [44, 12]
# ---------------(3, 77)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [45, 13]
# ---------------(3, 78)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [46, 14]
# ---------------(3, 79)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [47, 15]
# ---------------(3, 80)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [48, 16]
# ---------------(3, 81)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [49, 17]
# ---------------(3, 82)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [50, 18]
# ---------------(3, 83)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [51, 19]
# ---------------(3, 84)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [52, 20]
# ---------------(3, 85)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [53, 21]
# ---------------(3, 86)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [54, 22]
# ---------------(3, 87)-----------------
# index_h [0], index_w [1, 2], position_h [3], position_w [55, 23]
# ---------------(3, 88)-----------------
# ...
# index_h [2], index_w [2], position_h [62], position_w [38]
# ---------------(126, 103)-----------------
# index_h [2], index_w [2], position_h [62], position_w [39]
# ---------------(126, 104)-----------------
# index_h [2], index_w [2], position_h [62], position_w [40]
# ---------------(126, 105)-----------------
# index_h [2], index_w [2], position_h [62], position_w [41]
# ---------------(126, 106)-----------------
# index_h [2], index_w [2], position_h [62], position_w [42]
# ---------------(126, 107)-----------------
# index_h [2], index_w [2], position_h [62], position_w [43]
# ---------------(126, 108)-----------------
# index_h [2], index_w [2], position_h [62], position_w [44]
# ---------------(126, 109)-----------------
# index_h [2], index_w [2], position_h [62], position_w [45]
# ---------------(126, 110)-----------------
# index_h [2], index_w [2], position_h [62], position_w [46]
# ---------------(126, 111)-----------------
# index_h [2], index_w [2], position_h [62], position_w [47]
# ---------------(126, 112)-----------------
# index_h [2], index_w [2], position_h [62], position_w [48]
# ---------------(126, 113)-----------------
# index_h [2], index_w [2], position_h [62], position_w [49]
# ---------------(126, 114)-----------------
# index_h [2], index_w [2], position_h [62], position_w [50]
# ---------------(126, 115)-----------------
# index_h [2], index_w [2], position_h [62], position_w [51]
# ---------------(126, 116)-----------------
# index_h [2], index_w [2], position_h [62], position_w [52]
# ---------------(126, 117)-----------------
# index_h [2], index_w [2], position_h [62], position_w [53]
# ---------------(126, 118)-----------------
# index_h [2], index_w [2], position_h [62], position_w [54]
# ---------------(126, 119)-----------------
# index_h [2], index_w [2], position_h [62], position_w [55]
# ---------------(126, 120)-----------------
# index_h [2], index_w [2], position_h [62], position_w [56]
# ---------------(126, 121)-----------------
# index_h [2], index_w [2], position_h [62], position_w [57]
# ---------------(126, 122)-----------------
# index_h [2], index_w [2], position_h [62], position_w [58]
# ---------------(126, 123)-----------------
# index_h [2], index_w [2], position_h [62], position_w [59]
# ---------------(126, 124)-----------------
# index_h [2], index_w [2], position_h [62], position_w [60]
# ---------------(126, 125)-----------------
# index_h [2], index_w [2], position_h [62], position_w [61]
# ---------------(126, 126)-----------------
# index_h [2], index_w [2], position_h [62], position_w [62]
# ---------------(126, 127)-----------------
# index_h [2], index_w [2], position_h [62], position_w [63]
# ---------------(127, 0)-----------------
# index_h [2], index_w [0], position_h [63], position_w [0]
# ---------------(127, 1)-----------------
# index_h [2], index_w [0], position_h [63], position_w [1]
# ---------------(127, 2)-----------------
# index_h [2], index_w [0], position_h [63], position_w [2]
# ---------------(127, 3)-----------------
# index_h [2], index_w [0], position_h [63], position_w [3]
# ---------------(127, 4)-----------------
# index_h [2], index_w [0], position_h [63], position_w [4]
# ---------------(127, 5)-----------------
# index_h [2], index_w [0], position_h [63], position_w [5]
# ---------------(127, 6)-----------------
# index_h [2], index_w [0], position_h [63], position_w [6]
# ---------------(127, 7)-----------------
# index_h [2], index_w [0], position_h [63], position_w [7]
# ---------------(127, 8)-----------------
# index_h [2], index_w [0], position_h [63], position_w [8]
# ---------------(127, 9)-----------------
# index_h [2], index_w [0], position_h [63], position_w [9]
# ---------------(127, 10)-----------------
# index_h [2], index_w [0], position_h [63], position_w [10]
# ---------------(127, 11)-----------------
# index_h [2], index_w [0], position_h [63], position_w [11]
# ---------------(127, 12)-----------------
# index_h [2], index_w [0], position_h [63], position_w [12]
# ---------------(127, 13)-----------------
# index_h [2], index_w [0], position_h [63], position_w [13]
# ---------------(127, 14)-----------------
# index_h [2], index_w [0], position_h [63], position_w [14]
# ---------------(127, 15)-----------------
# index_h [2], index_w [0], position_h [63], position_w [15]
# ---------------(127, 16)-----------------
# index_h [2], index_w [0], position_h [63], position_w [16]
# ---------------(127, 17)-----------------
# index_h [2], index_w [0], position_h [63], position_w [17]
# ---------------(127, 18)-----------------
# index_h [2], index_w [0], position_h [63], position_w [18]
# ---------------(127, 19)-----------------
# index_h [2], index_w [0], position_h [63], position_w [19]
# ---------------(127, 20)-----------------
# index_h [2], index_w [0], position_h [63], position_w [20]
# ---------------(127, 21)-----------------
# index_h [2], index_w [0], position_h [63], position_w [21]
# ---------------(127, 22)-----------------
# index_h [2], index_w [0], position_h [63], position_w [22]
# ---------------(127, 23)-----------------
# index_h [2], index_w [0], position_h [63], position_w [23]
# ---------------(127, 24)-----------------
# index_h [2], index_w [0], position_h [63], position_w [24]
# ---------------(127, 25)-----------------
# index_h [2], index_w [0], position_h [63], position_w [25]
# ---------------(127, 26)-----------------
# index_h [2], index_w [0], position_h [63], position_w [26]
# ---------------(127, 27)-----------------
# index_h [2], index_w [0], position_h [63], position_w [27]
# ---------------(127, 28)-----------------
# index_h [2], index_w [0], position_h [63], position_w [28]
# ---------------(127, 29)-----------------
# index_h [2], index_w [0], position_h [63], position_w [29]
# ---------------(127, 30)-----------------
# index_h [2], index_w [0], position_h [63], position_w [30]
# ---------------(127, 31)-----------------
# index_h [2], index_w [0], position_h [63], position_w [31]
# ---------------(127, 32)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [32, 0]
# ---------------(127, 33)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [33, 1]
# ---------------(127, 34)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [34, 2]
# ---------------(127, 35)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [35, 3]
# ---------------(127, 36)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [36, 4]
# ---------------(127, 37)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [37, 5]
# ---------------(127, 38)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [38, 6]
# ---------------(127, 39)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [39, 7]
# ---------------(127, 40)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [40, 8]
# ---------------(127, 41)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [41, 9]
# ---------------(127, 42)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [42, 10]
# ---------------(127, 43)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [43, 11]
# ---------------(127, 44)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [44, 12]
# ---------------(127, 45)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [45, 13]
# ---------------(127, 46)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [46, 14]
# ---------------(127, 47)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [47, 15]
# ---------------(127, 48)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [48, 16]
# ---------------(127, 49)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [49, 17]
# ---------------(127, 50)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [50, 18]
# ---------------(127, 51)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [51, 19]
# ---------------(127, 52)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [52, 20]
# ---------------(127, 53)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [53, 21]
# ---------------(127, 54)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [54, 22]
# ---------------(127, 55)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [55, 23]
# ---------------(127, 56)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [56, 24]
# ---------------(127, 57)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [57, 25]
# ---------------(127, 58)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [58, 26]
# ---------------(127, 59)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [59, 27]
# ---------------(127, 60)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [60, 28]
# ---------------(127, 61)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [61, 29]
# ---------------(127, 62)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [62, 30]
# ---------------(127, 63)-----------------
# index_h [2], index_w [0, 1], position_h [63], position_w [63, 31]
# ---------------(127, 64)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [32, 0]
# ---------------(127, 65)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [33, 1]
# ---------------(127, 66)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [34, 2]
# ---------------(127, 67)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [35, 3]
# ---------------(127, 68)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [36, 4]
# ---------------(127, 69)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [37, 5]
# ---------------(127, 70)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [38, 6]
# ---------------(127, 71)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [39, 7]
# ---------------(127, 72)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [40, 8]
# ---------------(127, 73)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [41, 9]
# ---------------(127, 74)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [42, 10]
# ---------------(127, 75)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [43, 11]
# ---------------(127, 76)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [44, 12]
# ---------------(127, 77)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [45, 13]
# ---------------(127, 78)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [46, 14]
# ---------------(127, 79)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [47, 15]
# ---------------(127, 80)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [48, 16]
# ---------------(127, 81)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [49, 17]
# ---------------(127, 82)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [50, 18]
# ---------------(127, 83)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [51, 19]
# ---------------(127, 84)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [52, 20]
# ---------------(127, 85)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [53, 21]
# ---------------(127, 86)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [54, 22]
# ---------------(127, 87)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [55, 23]
# ---------------(127, 88)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [56, 24]
# ---------------(127, 89)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [57, 25]
# ---------------(127, 90)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [58, 26]
# ---------------(127, 91)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [59, 27]
# ---------------(127, 92)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [60, 28]
# ---------------(127, 93)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [61, 29]
# ---------------(127, 94)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [62, 30]
# ---------------(127, 95)-----------------
# index_h [2], index_w [1, 2], position_h [63], position_w [63, 31]
# ---------------(127, 96)-----------------
# index_h [2], index_w [2], position_h [63], position_w [32]
# ---------------(127, 97)-----------------
# index_h [2], index_w [2], position_h [63], position_w [33]
# ---------------(127, 98)-----------------
# index_h [2], index_w [2], position_h [63], position_w [34]
# ---------------(127, 99)-----------------
# index_h [2], index_w [2], position_h [63], position_w [35]
# ---------------(127, 100)-----------------
# index_h [2], index_w [2], position_h [63], position_w [36]
# ---------------(127, 101)-----------------
# index_h [2], index_w [2], position_h [63], position_w [37]
# ---------------(127, 102)-----------------
# index_h [2], index_w [2], position_h [63], position_w [38]
# ---------------(127, 103)-----------------
# index_h [2], index_w [2], position_h [63], position_w [39]
# ---------------(127, 104)-----------------
# index_h [2], index_w [2], position_h [63], position_w [40]
# ---------------(127, 105)-----------------
# index_h [2], index_w [2], position_h [63], position_w [41]
# ---------------(127, 106)-----------------
# index_h [2], index_w [2], position_h [63], position_w [42]
# ---------------(127, 107)-----------------
# index_h [2], index_w [2], position_h [63], position_w [43]
# ---------------(127, 108)-----------------
# index_h [2], index_w [2], position_h [63], position_w [44]
# ---------------(127, 109)-----------------
# index_h [2], index_w [2], position_h [63], position_w [45]
# ---------------(127, 110)-----------------
# index_h [2], index_w [2], position_h [63], position_w [46]
# ---------------(127, 111)-----------------
# index_h [2], index_w [2], position_h [63], position_w [47]
# ---------------(127, 112)-----------------
# index_h [2], index_w [2], position_h [63], position_w [48]
# ---------------(127, 113)-----------------
# index_h [2], index_w [2], position_h [63], position_w [49]
# ---------------(127, 114)-----------------
# index_h [2], index_w [2], position_h [63], position_w [50]
# ---------------(127, 115)-----------------
# index_h [2], index_w [2], position_h [63], position_w [51]
# ---------------(127, 116)-----------------
# index_h [2], index_w [2], position_h [63], position_w [52]
# ---------------(127, 117)-----------------
# index_h [2], index_w [2], position_h [63], position_w [53]
# ---------------(127, 118)-----------------
# index_h [2], index_w [2], position_h [63], position_w [54]
# ---------------(127, 119)-----------------
# index_h [2], index_w [2], position_h [63], position_w [55]
# ---------------(127, 120)-----------------
# index_h [2], index_w [2], position_h [63], position_w [56]
# ---------------(127, 121)-----------------
# index_h [2], index_w [2], position_h [63], position_w [57]
# ---------------(127, 122)-----------------
# index_h [2], index_w [2], position_h [63], position_w [58]
# ---------------(127, 123)-----------------
# index_h [2], index_w [2], position_h [63], position_w [59]
# ---------------(127, 124)-----------------
# index_h [2], index_w [2], position_h [63], position_w [60]
# ---------------(127, 125)-----------------
# index_h [2], index_w [2], position_h [63], position_w [61]
# ---------------(127, 126)-----------------
# index_h [2], index_w [2], position_h [63], position_w [62]
# ---------------(127, 127)-----------------
# index_h [2], index_w [2], position_h [63], position_w [63]

# %%
import deepinv as dinv 
from deepinv.physics.generator import DiffractionBlurGenerator, ProductConvolutionPatchBlurGenerator

psf_size = (31, 31)
patch_size = (128, 128)
overlap = (40, 40)
image_size = 256
image = torch.zeros(2, 3, image_size, image_size, device=device)

diffraction_generator = DiffractionBlurGenerator(psf_size,  device=device)
generator = ProductConvolutionPatchBlurGenerator(psf_generator=diffraction_generator,
                                                    image_size=image_size,
                                                    patch_size=patch_size,
                                                    overlap=overlap,
                                                    device=device)
params = generator.step(2)
h = params['filters']
w = params['multipliers']

physic = dinv.physics.SpaceVaryingBlur(filters=h, multipliers=w, padding='valid', method='product_convolution2d_patch', patch_size=patch_size, overlap=overlap, device='cuda')

max_size = 150
for i in range(psf_size[0], max_size):
    for j in range(psf_size[1], max_size):
        image = torch.zeros(2, 3, 256, 256)
        position = (i, j)
        image[..., position[0]: position[0] + 1, position[1]: position[1] + 1] = 1.
        blurry = physic.A(image)
        psf_pc = blurry[:,0:1, 
                        position[0] - psf_size[0] + 1: position[0] + 1, 
                        position[1] - psf_size[1] + 1: position[1] + 1]

        psf_hat = physic.get_psf(position).flatten(0,1)
        diff = psf_pc - psf_hat
        if torch.norm(diff) > 1e-5:
            print(f'{i, j}: ', torch.norm(diff))
            show_images([psf_pc, psf_hat, psf_pc - psf_hat])
            break

# %% [markdown]
# ### Optimized version

# %%
def generate_random_patch(tensor: Tensor, centers: Tensor, patch_size: tuple[int]):
    """
    Args:
        tensor (Tensor): Tensor of patch_size (B, C, H, W) to be cropped.
        centers (Tensor): (B, num_patches, 2)
    Returns:
        Tensor: Randomly cropped Tensor of shape (B, C, num_patches, patch_size, patch_size)
    """
    device = tensor.device

    if isinstance(patch_size, int):
        patch_size = (patch_size, patch_size)

    patch_size_h, patch_size_w = patch_size

    i, j = centers[..., 0:1],  centers[..., 1:2]

    # B, num_patches, patch_size
    rows = torch.arange(-patch_size_h//2 + patch_size_h % 2, patch_size_h//2 + patch_size_h % 2, dtype=torch.long, device=device) + i
    columns = torch.arange(-patch_size_w//2 + patch_size_w % 2, patch_size_w//2 + patch_size_w % 2, dtype=torch.long, device=device) + j

    patches = tensor[torch.arange(tensor.size(0), device=tensor.device, dtype=torch.long)[:, None, None, None],
                      :, 
                    rows[..., None],
                    columns[...,None, :]]

    return patches.permute(0, -1, 1, 2, 3)

# %%
h.shape
# Out:
# torch.Size([2, 1, 9, 51, 51])

# %%
import deepinv as dinv 
from deepinv.physics.generator import DiffractionBlurGenerator, ProductConvolutionPatchBlurGenerator
import torch.nn.functional as F 
from torchvision.transforms.functional import center_crop

psf_size = (51, 51)
patch_size = (256, 256)
overlap = (128, 128)
stride = (patch_size[0] - overlap[0], patch_size[1] - overlap[1])
image_size = 1024
device='cuda'

diffraction_generator = DiffractionBlurGenerator(psf_size,  device=device)
generator = ProductConvolutionPatchBlurGenerator(psf_generator=diffraction_generator,
                                                    image_size=image_size,
                                                    patch_size=(512, 512),
                                                    overlap=(256, 256),
                                                    device=device)
params = generator.step(2)
h = params['filters']
w = params['multipliers']

physic = dinv.physics.SpaceVaryingBlur(filters=h, multipliers=w, padding='valid', method='product_convolution2d_patch', patch_size=(512, 512), overlap=(256, 256), device='cuda')

random_patch = False
# image = torch.zeros(2, 3, image_size, image_size, device=device)
# image[...,patch_size[0] // 2::stride[0], patch_size[1] // 2::stride[1]] = 1.
for it in range(100):
    if random_patch:       
        centers = torch.randint(patch_size[0] // 2, image_size - patch_size[0] // 2, size=(2, 10, 2), device='cuda')
    else:
        row = torch.arange(
            patch_size[0] // 2, image_size , patch_size[0] - overlap[0], device=device)
        col = torch.arange(
            patch_size[1] // 2, image_size , patch_size[1] - overlap[1], device=device)

        row, col = torch.meshgrid(row, col, indexing='ij')
        centers = torch.stack((row.flatten(),
                                col.flatten()), dim=1).unsqueeze(0) #.expand(2, -1, -1)
    
    image = torch.zeros(2, 3, image_size, image_size, device=device)

    image[torch.arange(2)[:,None],
          :,
          centers[...,0],
          centers[...,1],
        ] = 1.
    
    
    blurry = physic.A(image)
    blurry_padded = F.pad(blurry, (psf_size[1] // 2, psf_size[1] // 2, psf_size[0] // 2, psf_size[0] // 2), mode='constant', value=0)

    psf_pc = generate_random_patch(blurry_padded, centers=centers, patch_size=psf_size).transpose(1,2).flatten(0,1)[:,0:1]

    psf_hat = physic.get_psf_optimized(centers).transpose(1,2).flatten(0,1)[:,0:1]
    
    
    diff = psf_pc - psf_hat
    # print(torch.norm(diff))
    if torch.norm(diff) > 1e-5:
        print(it)
        show_images(psf_pc[:5])
        show_images(psf_hat[:5])
        show_images(psf_pc[:5] - psf_hat[:5], colorbar=True)
        break

    # if not random_patch:
    #     break

# %%
show_images(image, figsize=20)

# %%
(psf_pc - psf_hat).abs().max()
# Out:
# tensor(7.4506e-09, device='cuda:0')

# %%
show_images(psf_pc[:5])
show_images(psf_hat[:5])
show_images(psf_pc[:5] - psf_hat[:5], colorbar=True)

# %%
import deepinv as dinv 
from deepinv.physics.generator import DiffractionBlurGenerator, ProductConvolutionPatchBlurGenerator
import torch.nn.functional as F 
from torchvision.transforms.functional import center_crop

psf_size = (51, 51)
patch_size = (512, 512)
overlap = (256, 256)
stride = (patch_size[0] - overlap[0], patch_size[1] - overlap[1])
image_size = 1024
device='cuda'

diffraction_generator = DiffractionBlurGenerator(psf_size,  device=device, apodize=True)
generator = ProductConvolutionPatchBlurGenerator(psf_generator=diffraction_generator,
                                                    image_size=image_size,
                                                    patch_size=patch_size,
                                                    overlap=overlap,
                                                    device=device)
params = generator.step(1)
h = params['filters']
w = params['multipliers']

physic = dinv.physics.SpaceVaryingBlur(filters=h, multipliers=w, padding='valid', method='product_convolution2d_patch', patch_size=patch_size, overlap=overlap, device='cuda')

random_patch = False
for it in range(100):
    if random_patch:       
        centers = torch.randint(patch_size[0], image_size - patch_size[0], size=(2, 10, 2), device='cuda')
    else:
        row = torch.arange(
            patch_size[0] // 2, image_size - patch_size[0] // 2 + 1, patch_size[0] - overlap[0], device=device)
        col = torch.arange(
            patch_size[1] // 2, image_size - patch_size[1] // 2 + 1, patch_size[1] - overlap[1], device=device)

        row, col = torch.meshgrid(row, col, indexing='ij')
        centers = torch.stack((row.flatten(),
                                col.flatten()), dim=1).unsqueeze(0) #.expand(2, -1, -1)
    
    image = torch.zeros(1, 3, image_size, image_size, device=device)

    image[torch.arange(1)[:,None],
          :,
          centers[...,0],
          centers[...,1],
        ] = 1.
    
    
    blurry = physic.A(image)
    blurry_padded = F.pad(blurry, (psf_size[1] // 2, psf_size[1] // 2, psf_size[0] // 2, psf_size[0] // 2), mode='constant', value=0)

    psf_pc = generate_random_patch(blurry_padded, centers=centers, patch_size=psf_size).transpose(1,2).flatten(0,1)[:,0:1]

    psf_hat = physic.get_psf_optimized(centers).transpose(1,2).flatten(0,1)[:,0:1]
    
    
    diff = psf_pc - psf_hat
    # print(torch.norm(diff))
    if torch.norm(diff) > 1e-5:
        print(it)
        show_images(psf_pc, ncols=3, colorbar=True)
        show_images(psf_hat, ncols=3, colorbar=True)
        show_images((psf_pc - psf_hat).abs() ** 0.1, colorbar=True, ncols=3)
        break

    # if not random_patch:
    #     break

# %%
import deepinv as dinv 
from deepinv.physics.generator import DiffractionBlurGenerator, ProductConvolutionPatchBlurGenerator
import torch.nn.functional as F 
from torchvision.transforms.functional import center_crop

psf_size = (51, 51)
patch_size = (512, 512)
overlap = (256, 256)
stride = (patch_size[0] - overlap[0], patch_size[1] - overlap[1])
image_size = 1024
device='cuda'

diffraction_generator = DiffractionBlurGenerator(psf_size,  device=device, apodize=True)
generator = ProductConvolutionPatchBlurGenerator(psf_generator=diffraction_generator,
                                                    image_size=image_size,
                                                    patch_size=patch_size,
                                                    overlap=overlap,
                                                    device=device)
params = generator.step(1)
h = params['filters']
w = params['multipliers']

physic = dinv.physics.SpaceVaryingBlur(filters=h, multipliers=w, padding='valid', method='product_convolution2d_patch', patch_size=patch_size, overlap=overlap, device='cuda')

random_patch = False
for it in range(100):
    if random_patch:       
        centers = torch.randint(patch_size[0] // 2, image_size - patch_size[0] // 2, size=(2, 10, 2), device='cuda')
    else:
        row = torch.arange(
            patch_size[0] // 4, image_size - patch_size[0] // 4 + 1, (patch_size[0] - overlap[0]) // 2, device=device)
        col = torch.arange(
            patch_size[1] // 4, image_size - patch_size[1] // 4 + 1, (patch_size[1] - overlap[1] ) // 2, device=device)

        row, col = torch.meshgrid(row, col, indexing='ij')
        centers = torch.stack((row.flatten(),
                                col.flatten()), dim=1).unsqueeze(0) #.expand(2, -1, -1)
    
    image = torch.zeros(1, 3, image_size, image_size, device=device)

    image[torch.arange(1)[:,None],
          :,
          centers[...,0],
          centers[...,1],
        ] = 1.
    
    
    blurry = physic.A(image)
    blurry_padded = F.pad(blurry, (psf_size[1] // 2, psf_size[1] // 2, psf_size[0] // 2, psf_size[0] // 2), mode='constant', value=0)

    psf_pc = generate_random_patch(blurry_padded, centers=centers, patch_size=psf_size).transpose(1,2).flatten(0,1)[:,0:1]

    psf_hat = physic.get_psf_optimized(centers).transpose(1,2).flatten(0,1)[:,0:1]
    
    
    diff = psf_pc - psf_hat
    # print(torch.norm(diff))
    if torch.norm(diff) > 1e-5:
        print(it)
        show_images(psf_pc, ncols=7)
        show_images(psf_hat, ncols=7)
        show_images((psf_pc - psf_hat).abs() ** 0.1, colorbar=True, ncols=7)
        break

    # if not random_patch:
    #     break

# %%
psf_hat.shape
# Out:
# torch.Size([98, 1, 51, 51])

# %% [markdown]
# ## TEST ADJOINTNESS

# %%
psf_size = (31, 31)
patch_size = (128, 128)
overlap = (64, 64)
stride = (patch_size[0] - overlap[0], patch_size[1] - overlap[1])
image_size = 512
device='cuda'

diffraction_generator = DiffractionBlurGenerator(psf_size,  device=device)
generator = ProductConvolutionPatchBlurGenerator(psf_generator=diffraction_generator,
                                                    image_size=image_size,
                                                    patch_size=patch_size,
                                                    overlap=overlap,
                                                    device=device)
params = generator.step(2)
h = params['filters']
w = params['multipliers']

physic = dinv.physics.SpaceVaryingBlur(filters=h, multipliers=w, padding='valid', method='product_convolution2d_patch', patch_size=patch_size, overlap=overlap, image_size=image_size, device='cuda')

x = torch.randn(2,3,image_size,image_size)
Ax = physic.A(x) 
y = torch.randn_like(Ax)
ATy = physic.A_adjoint(y)

left = (Ax * y).view(x.size(0), -1).sum(dim = 1)
right = (ATy * x).view(y.size(0), -1).sum(dim = 1)

print((left - right).abs())
assert torch.allclose(left, right, atol=1e-6), "Adjointness Test Failed"
# Out:
# tensor([6.1035e-05, 1.5259e-05], device='cuda:0')

# %% [markdown]
# ## Time

# %%
from torch.utils.benchmark import Timer

# %%
image_size = 1024
patch_size = 256
overlap = 128
psf_size = 31

from deepinv.physics.generator import ProductConvolutionPatchBlurGenerator
from deepinv.physics import SpaceVaryingBlur

psf_generator = DiffractionBlurGenerator(
    (psf_size, psf_size), num_channels=3, fc=0.2, device=device, dtype=dtype)

pc_generator = ProductConvolutionPatchBlurGenerator(
    psf_generator=psf_generator,
    image_size=image_size,
    patch_size=patch_size,
    overlap=overlap,
    device=device
)
params_pc = pc_generator.step(1)
physics = SpaceVaryingBlur(method="product_convolution2d_patch",
                           patch_size= patch_size, 
                           overlap=overlap,
                           device=device,
                           image_size=image_size,
                            **params_pc, )
batch_size = 8
n_patch = 32
params = pc_generator.step(batch_size)
centers = torch.randint(patch_size //2, image_size - patch_size // 2, size = (batch_size, n_patch, 2))

# %%
psf_1 = physics.get_psf(centers, **params)
print(psf_1.shape)
# Out:
# torch.Size([8, 3, 32, 31, 31])

# %%
psf_2 = physics.get_psf_optimized(centers, **params)
print(psf_2.shape)
# Out:
# torch.Size([8, 3, 32, 31, 31])

# %%
print(torch.allclose(psf_1, psf_2))
# Out:
# True

# %%
timer = Timer(stmt='physics.get_psf(centers, **params)',
    globals=globals())
timer.blocked_autorange(min_run_time=5)
# Out:
# <torch.utils.benchmark.utils.common.Measurement object at 0x78826178dc10>
# physics.get_psf(centers, **params)
#   Median: 61.99 ms
#   IQR:    2.06 ms (61.84 to 63.91)
#   8 measurements, 10 runs per measurement, 1 thread

# %%
timer = Timer(stmt='physics.get_psf_optimized(centers, **params)',
    globals=globals())
timer.blocked_autorange(min_run_time=5)
# Out:
# <torch.utils.benchmark.utils.common.Measurement object at 0x7a8b454b0490>
# physics.get_psf_optimized(centers, **params)
#   Median: 15.64 ms
#   IQR:    9.06 ms (7.50 to 16.56)
#   38 measurements, 10 runs per measurement, 1 thread
#   WARNING: Interquartile range is 58.0% of the median measurement.
#            This suggests significant environmental influence.

# %%
timer = Timer(stmt='physics.get_psf_optimized(centers, **params)',
    globals=globals())
timer.blocked_autorange(min_run_time=5)
# Out:
# <torch.utils.benchmark.utils.common.Measurement object at 0x7882543eb320>
# physics.get_psf_optimized(centers, **params)
#   Median: 2.21 ms
#   IQR:    0.09 ms (2.15 to 2.24)
#   23 measurements, 100 runs per measurement, 1 thread
